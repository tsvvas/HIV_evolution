# %% [markdown]
# ### At the begginig a bit data ( from table ) preprocessing

# %%
import numpy as np
import pandas as pd
import Bio as bio

# %%
Proteins_data = pd.read_csv('proteins_data/prot_data.csv')
Proteins_data
# Out:
#                     Organism  \
# 0       Campylobacter jejuni
# 1       Campylobacter jejuni
# 2       Campylobacter jejuni
# 3       Campylobacter jejuni
# 4       Campylobacter jejuni
# 5       Campylobacter jejuni
# 6       Campylobacter jejuni
# 7       Campylobacter jejuni
# 8       Campylobacter jejuni
# 9       Campylobacter jejuni
# 10      Campylobacter jejuni
# 11      Campylobacter jejuni
# 12      Campylobacter jejuni
# 13      Campylobacter jejuni
# 14      Campylobacter jejuni
# 15      Campylobacter jejuni
# 16      Campylobacter jejuni
# 17      Campylobacter jejuni
# 18      Campylobacter jejuni
# 19      Campylobacter jejuni
# 20      Campylobacter jejuni
# 21      Campylobacter jejuni
# 22      Campylobacter jejuni
# 23      Campylobacter jejuni
# 24      Campylobacter jejuni
# 25      Campylobacter jejuni
# 26      Campylobacter jejuni
# 27      Campylobacter jejuni
# 28      Campylobacter jejuni
# 29      Campylobacter jejuni
# ...                      ...
# 106519       Yersinia pestis
# 106520       Yersinia pestis
# 106521       Yersinia pestis
# 106522       Yersinia pestis
# 106523       Yersinia pestis
# 106524       Yersinia pestis
# 106525       Yersinia pestis
# 106526       Yersinia pestis
# 106527       Yersinia pestis
# 106528       Yersinia pestis
# 106529       Yersinia pestis
# 106530       Yersinia pestis
# 106531       Yersinia pestis
# 106532       Yersinia pestis
# 106533       Yersinia pestis
# 106534       Yersinia pestis
# 106535       Yersinia pestis
# 106536       Yersinia pestis
# 106537       Yersinia pestis
# 106538       Yersinia pestis
# 106539       Yersinia pestis
# 106540       Yersinia pestis
# 106541       Yersinia pestis
# 106542       Yersinia pestis
# 106543       Yersinia pestis
# 106544       Yersinia pestis
# 106545       Yersinia pestis
# 106546       Yersinia pestis
# 106547       Yersinia pestis
# 106548       Yersinia pestis
#
#                                                   Protein       ALA       ARG  \
# 0       sp|Q0PAS7|CMOA_CAMJE Carboxy-S-adenosyl-L-meth...  0.080851  0.025532
# 1       sp|Q9PMD9|COAE_CAMJE Dephospho-CoA kinase OS=C...  0.079602  0.029851
# 2       sp|Q9PP06|APT_CAMJE Adenine phosphoribosyltran...  0.071429  0.032967
# 3       sp|Q0PC30|ATPB_CAMJE ATP synthase subunit beta...  0.083871  0.038710
# 4       sp|Q9PJ53|AROQ_CAMJE 3-dehydroquinate dehydrat...  0.088050  0.037736
# 5       sp|Q0P899|CAS2_CAMJE CRISPR-associated endorib...  0.020979  0.027972
# 6       sp|Q9PJ21|ATPA_CAMJE ATP synthase subunit alph...  0.097804  0.051896
# 7       sp|Q46104|ARLY_CAMJE Argininosuccinate lyase O...  0.071739  0.032609
# 8       sp|Q0P7U6|BIOB_CAMJE Biotin synthase OS=Campyl...  0.086331  0.035971
# 9       sp|Q9PJ20|ATPG_CAMJE ATP synthase gamma chain ...  0.074830  0.027211
# 10      sp|P54413|CLPP_CAMJE ATP-dependent Clp proteas...  0.087629  0.046392
# 11      sp|Q9PHZ4|CRCB_CAMJE Putative fluoride ion tra...  0.049180  0.008197
# 12      sp|Q0P9F1|CSRA_CAMJE Translational regulator C...  0.026667  0.026667
# 13      sp|Q0PC33|ATPD_CAMJE ATP synthase subunit delt...  0.052023  0.040462
# 14      sp|Q9PNI7|CLPS_CAMJE ATP-dependent Clp proteas...  0.062500  0.000000
# 15      sp|Q9PIL7|CARB_CAMJE Carbamoyl-phosphate synth...  0.079890  0.036731
# 16      sp|Q9PPF2|COAD_CAMJE Phosphopantetheine adenyl...  0.075949  0.031646
# 17      sp|Q9PI02|CLPB_CAMJE Chaperone protein ClpB OS...  0.091015  0.039673
# 18      sp|Q0PAS0|ALF_CAMJE Fructose-bisphosphate aldo...  0.084746  0.019774
# 19      sp|Q9PP26|ALR_CAMJE Alanine racemase OS=Campyl...  0.070122  0.042683
# 20      sp|Q9PIS0|ARGC_CAMJE N-acetyl-gamma-glutamyl-p...  0.067251  0.029240
# 21      sp|Q0P952|ATP6_CAMJE ATP synthase subunit a OS...  0.092920  0.030973
# 22      sp|Q9PIR7|ARGD_CAMJE Acetylornithine aminotran...  0.089059  0.022901
# 23      sp|Q9PPI1|CORA_CAMJE Magnesium transport prote...  0.055046  0.045872
# 24      sp|Q9PIR8|ARGB_CAMJE Acetylglutamate kinase OS...  0.082437  0.014337
# 25      sp|Q9PPL8|ACKA_CAMJE Acetate kinase OS=Campylo...  0.070707  0.045455
# 26      sp|Q9PMG8|CARA_CAMJE Carbamoyl-phosphate synth...  0.056452  0.024194
# 27      sp|Q9PIJ1|BIOD_CAMJE ATP-dependent dethiobioti...  0.059701  0.004975
# 28      sp|Q9PP70|GSA_CAMJE Glutamate-1-semialdehyde 2...  0.096698  0.018868
# 29      sp|Q9PNN2|GATA_CAMJE Glutamyl-tRNA(Gln) amidot...  0.103753  0.026490
# ...                                                   ...       ...       ...
# 106519  tr|Q7CIW4|Q7CIW4_YERPE Putative chaperone prot...  0.084942  0.069498
# 106520  tr|Q9ZC82|Q9ZC82_YERPE 102 kbases unstable reg...  0.085821  0.063433
# 106521  tr|Q9RIC4|Q9RIC4_YERPE Uncharacterized protein...  0.109890  0.076923
# 106522  tr|Q7ARG3|Q7ARG3_YERPE Phage lambda tail assem...  0.061538  0.041026
# 106523  tr|Q7ARB5|Q7ARB5_YERPE Putative resolvase OS=Y...  0.106796  0.101942
# 106524  tr|O68704|O68704_YERPE Putative virulence dete...  0.032967  0.032967
# 106525  tr|Q9ZC57|Q9ZC57_YERPE Putative thioredoxin OS...  0.084848  0.030303
# 106526  tr|Q7ARB8|Q7ARB8_YERPE Putative DNA-binding pr...  0.077419  0.090323
# 106527  tr|Q9X6B4|Q9X6B4_YERPE Anaerobic dimethyl sulf...  0.087413  0.041958
# 106528  tr|Q7BTX0|Q7BTX0_YERPE Putative yopH targeting...  0.056738  0.035461
# 106529  tr|Q9ZC65|Q9ZC65_YERPE Putative GntR-family re...  0.097252  0.065539
# 106530  tr|O68768|O68768_YERPE Uncharacterized protein...  0.133690  0.053476
# 106531  tr|Q9RH45|Q9RH45_YERPE Quorum-sensing transcri...  0.048980  0.032653
# 106532  tr|Q9R323|Q9R323_YERPE Uncharacterized protein...  0.065421  0.093458
# 106533  tr|Q9ZC22|Q9ZC22_YERPE Putative exported solut...  0.111374  0.021327
# 106534  tr|Q7ARJ2|Q7ARJ2_YERPE Uncharacterized protein...  0.093525  0.021583
# 106535  tr|O68771|O68771_YERPE CobS homolog OS=Yersini...  0.090024  0.041363
# 106536  tr|Q7ARE8|Q7ARE8_YERPE Terminase_6 domain-cont...  0.064593  0.069378
# 106537  tr|O68779|O68779_YERPE Mutator family transpos...  0.084577  0.044776
# 106538  tr|O68699|O68699_YERPE Putative Yop negative r...  0.120915  0.032680
# 106539  tr|O68730|O68730_YERPE Uncharacterized protein...  0.066667  0.009524
# 106540  tr|Q9RCC8|Q9RCC8_YERPE Putative exported prote...  0.058548  0.044496
# 106541  tr|Q9ZC60|Q9ZC60_YERPE Putative peptidase OS=Y...  0.088889  0.044444
# 106542  tr|Q9RCC6|Q9RCC6_YERPE Mannosyltransferase-lik...  0.062315  0.032641
# 106543  tr|Q7ARD2|Q7ARD2_YERPE Uncharacterized protein...  0.081081  0.036036
# 106544  tr|Q9ZC37|Q9ZC37_YERPE Putative transcription ...  0.072222  0.061111
# 106545  tr|Q9RIB8|Q9RIB8_YERPE Uncharacterized protein...  0.071429  0.014286
# 106546  tr|Q9ZC76|Q9ZC76_YERPE Putative chlorohydrolas...  0.092105  0.061404
# 106547  tr|O68728|O68728_YERPE Phage lambda-related ta...  0.054054  0.072072
# 106548  tr|Q9ZC24|Q9ZC24_YERPE Putative binding-protei...  0.061818  0.040000
#
#              ASN       ASP       CYS       GLN       GLU       GLY  ...  \
# 0       0.068085  0.059574  0.021277  0.029787  0.080851  0.029787  ...
# 1       0.059701  0.044776  0.009950  0.029851  0.094527  0.029851  ...
# 2       0.054945  0.060440  0.021978  0.021978  0.071429  0.049451  ...
# 3       0.034409  0.068817  0.002151  0.027957  0.077419  0.092473  ...
# 4       0.056604  0.025157  0.018868  0.075472  0.075472  0.081761  ...
# 5       0.090909  0.034965  0.006993  0.048951  0.083916  0.041958  ...
# 6       0.031936  0.051896  0.001996  0.039920  0.083832  0.085828  ...
# 7       0.043478  0.063043  0.013043  0.036957  0.078261  0.050000  ...
# 8       0.043165  0.032374  0.039568  0.053957  0.100719  0.064748  ...
# 9       0.071429  0.040816  0.006803  0.034014  0.098639  0.030612  ...
# 10      0.025773  0.061856  0.015464  0.036082  0.067010  0.067010  ...
# 11      0.073770  0.000000  0.008197  0.024590  0.000000  0.098361  ...
# 12      0.040000  0.053333  0.000000  0.053333  0.093333  0.066667  ...
# 13      0.098266  0.046243  0.011561  0.040462  0.104046  0.011561  ...
# 14      0.052083  0.041667  0.010417  0.072917  0.093750  0.031250  ...
# 15      0.044077  0.060606  0.013774  0.023875  0.077135  0.064279  ...
# 23      0.027523  0.058104     0.0
# 24      0.017921  0.064516     0.0
# 25      0.030303  0.063131     0.0
# 26      0.048387  0.069892     0.0
# 27      0.039801  0.024876     0.0
# 28      0.030660  0.044811     0.0
# 29      0.055188  0.057395     0.0
# ...          ...       ...     ...
# 106519  0.019305  0.081081     0.0
# 106520  0.033582  0.048507     0.0
# 106521  0.000000  0.076923     0.0
# 106522  0.020513  0.076923     0.0
# 106523  0.019417  0.053398     0.0
# 106524  0.049451  0.049451     0.0
# 106525  0.030303  0.090909     0.0
# 106526  0.027957  0.079570     0.0
# 106527  0.027972  0.111888     0.0
# 106528  0.014184  0.063830     0.0
# 106529  0.027484  0.054968     0.0
# 106530  0.026738  0.069519     0.0
# 106531  0.048980  0.057143     0.0
# 106532  0.018692  0.056075     0.0
# 106533  0.042654  0.059242     0.0
# 106534  0.064748  0.057554     0.0
# 106535  0.038929  0.063260     0.0
# 106536  0.028708  0.078947     0.0
# 106537  0.032338  0.062189     0.0
# 106538  0.009804  0.062092     0.0
# 106539  0.019048  0.104762     0.0
# 106540  0.065574  0.060890     0.0
# 106541  0.027160  0.081481     0.0
# 106542  0.071217  0.086053     0.0
# 106543  0.072072  0.135135     0.0
# 106544  0.038889  0.100000     0.0
# 106545  0.014286  0.057143     0.0
# 106546  0.037281  0.074561     0.0
# 106547  0.072072  0.099099     0.0
# 106548  0.036364  0.094545     0.0
#
# [106549 rows x 23 columns]

# %%
# Be careful with your data

Data_anal = Proteins_data

labels_categorized = Data_anal[Data_anal.columns[0]].values
feature_matrix = Data_anal[Data_anal.columns[2:22]].values

# in feature matrix we can get rid of 'Anyone' ('X') - means any amino acid, because it's useless shit

feature_matrix
# Out:
# array([[0.08085106, 0.02553191, 0.06808511, ..., 0.00425532, 0.03829787,
#         0.03829787],
#        [0.07960199, 0.02985075, 0.05970149, ..., 0.        , 0.01492537,
#         0.03482587],
#        [0.07142857, 0.03296703, 0.05494505, ..., 0.        , 0.03846154,
#         0.03846154],
#        ...,
#        [0.09210526, 0.06140351, 0.01973684, ..., 0.02192982, 0.0372807 ,
#         0.0745614 ],
#        [0.05405405, 0.07207207, 0.05405405, ..., 0.02702703, 0.07207207,
#         0.0990991 ],
#        [0.06181818, 0.04      , 0.02181818, ..., 0.01818182, 0.03636364,
#         0.09454545]])

# %%
# Making labels not categorized (slightly)

labels = []

for x in labels_categorized:
    if x == 'Human':
        labels.append(1)
    else:
        labels.append(0)
        
Data_anal['Label'] = labels

# %% [markdown]
# ### Looking at our data

# %%
# Useful thing

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# To see

print(Data_anal.columns)
# Out:
# Index(['Organism', 'Protein', 'ALA', 'ARG', 'ASN', 'ASP', 'CYS', 'GLN', 'GLU',
#        'GLY', 'HIS', 'ILE', 'LEU', 'LYS', 'MET', 'PHE', 'PRO', 'SER', 'THR',
#        'TRP', 'TYR', 'VAL', 'Anyone', 'Label'],
#       dtype='object')

# %%
# Data preparing
def for_plot_analyze(label_1, label_2):

    protein_1 = Data_anal[label_1]
    protein_2 = Data_anal[label_2]

    prot_human_1 = []
    prot_other_1 = []

    prot_human_2 = []
    prot_other_2 = []

    for i in range(len(protein_1)):
        if labels[i] == 0:
            prot_other_1.append(protein_1[i])
            prot_other_2.append(protein_2[i])
        else:
            prot_human_1.append(protein_1[i])
            prot_human_2.append(protein_2[i])

    return prot_human_1, prot_human_2, prot_other_1, prot_other_2

# %%
# prot dividing

prot_human_ala, prot_human_arg, prot_other_ala, prot_other_arg = for_plot_analyze('ALA', 'ARG')
prot_human_asp, prot_human_cys, prot_other_asp, prot_other_cys = for_plot_analyze('ASP', 'CYS')
prot_human_glu, prot_human_gly, prot_other_glu, prot_other_gly = for_plot_analyze('GLU', 'GLY')
prot_human_ile, prot_human_leu, prot_other_ile, prot_other_leu = for_plot_analyze('ILE', 'LEU')

#print(prot_human_ala)

# %%
# Plotting

fig = plt.figure(figsize = (12 , 8))

fig.suptitle('Proteins difference Human vs. Viruses,Bacteria')

# ALA and ARG
ax_1 = fig.add_subplot(2,2,1)

ax_1.scatter(prot_other_ala, prot_other_arg, color = 'red', alpha = 1, label = 'viruses and bacteria')
ax_1.scatter(prot_human_ala, prot_human_arg, color = 'green', alpha = 0.1, label = 'human')
ax_1.set_title('ALA' + ' and ' + 'ARG')
#ax.title(123)
ax_1.set_xlabel('ALA')
ax_1.set_ylabel('ARG')
ax_1.legend()

# ASP and CYS
ax_2 = fig.add_subplot(2,2,2)

ax_2.scatter(prot_other_asp, prot_other_cys, color = 'red', alpha = 1, label = 'viruses and bacteria')
ax_2.scatter(prot_human_asp, prot_human_cys, color = 'green', alpha = 0.1, label = 'human')
ax_2.set_title('ASP' + ' and ' + 'CYS')
#ax.title(123)
ax_2.set_xlabel('ASP')
ax_2.set_ylabel('CYS')
ax_2.legend()

# GLU and GLY
ax_3 = fig.add_subplot(2,2,3)

ax_3.scatter(prot_other_glu, prot_other_gly, color = 'red', alpha = 1, label = 'viruses and bacteria')
ax_3.scatter(prot_human_glu, prot_human_gly, color = 'green', alpha = 0.1, label = 'human')
ax_3.set_title('GLU' + ' and ' + 'GLY')
#ax.title(123)
ax_3.set_xlabel('GLU')
ax_3.set_ylabel('GLY')
ax_3.legend()

# GLU and GLY
ax_4 = fig.add_subplot(2,2,4)

ax_4.scatter(prot_other_ile, prot_other_leu, color = 'red', alpha = 1, label = 'viruses and bacteria')
ax_4.scatter(prot_human_ile, prot_human_leu, color = 'green', alpha = 0.1, label = 'human')
ax_4.set_title('ILE' + ' and ' + 'LEU')
#ax.title(123)
ax_4.set_xlabel('ILE')
ax_4.set_ylabel('LEU')
ax_4.legend()



plt.show()

# %%
# Violin plot
# !!! NOT WORKING. TODO: analyze this shit !!!

f, ax = plt.subplots(1, 1, figsize=(18,8))

sns.violinplot('ALA','ARG', hue='Label', data = Data_anal , split=True, ax=ax[0])
ax[0].set_title('ALA and ARG')
ax[0].set_yticks(range(0, 1, 20))

plt.show()

# %%
# Simple math stats

Proteins_data.describe()
# Out:
#                  ALA            ARG            ASN            ASP  \
# count  106549.000000  106549.000000  106549.000000  106549.000000
# mean        0.078174       0.058233       0.035695       0.048206
# std         0.035954       0.029205       0.020932       0.022794
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.053824       0.039474       0.021645       0.033708
# 50%         0.073171       0.054945       0.033613       0.047782
# 75%         0.098039       0.072727       0.046751       0.061069
# max         0.509804       0.500000       0.287234       0.349391
#
#                  CYS            GLN            GLU            GLY  \
# count  106549.000000  106549.000000  106549.000000  106549.000000
# mean        0.020082       0.044082       0.065175       0.068536
# std         0.021020       0.023971       0.032442       0.031735
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.007722       0.028866       0.044776       0.048544
# 50%         0.015873       0.041618       0.062500       0.065744
# 75%         0.026316       0.055556       0.081325       0.084592
# max         0.411765       0.987500       0.500000       0.750000
#
#                  HIS            ILE  ...            LYS            MET  \
# count  106549.000000  106549.000000  ...  106549.000000  106549.000000
# mean        0.024341       0.048445  ...       0.054749       0.025823
# std         0.015977       0.027242  ...       0.033570       0.015657
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.014085       0.030059  ...       0.030888       0.016000
# 50%         0.022727       0.045714  ...       0.050228       0.023256
# 75%         0.032143       0.062937  ...       0.072981       0.032258
# max         0.437500       0.500000  ...       0.461538       0.333333
#
#                  PHE            PRO            SER            THR  \
# count  106549.000000  106549.000000  106549.000000  106549.000000
# mean        0.037843       0.056349       0.074884       0.052541
# std         0.021495       0.033657       0.032867       0.022788
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.023810       0.035484       0.053719       0.039437
# 50%         0.035398       0.050420       0.070175       0.050987
# 75%         0.048843       0.069832       0.090476       0.063291
# max         0.466667       0.473118       0.670543       0.600000
#
#                  TRP            TYR            VAL         Anyone
# count  106549.000000  106549.000000  106549.000000  106549.000000
# mean        0.013782       0.027042       0.063639       0.000765
# std         0.012501       0.017389       0.025565       0.004160
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.005076       0.015544       0.047368       0.000000
# 50%         0.011494       0.025440       0.062500       0.000000
# 75%         0.019608       0.036364       0.078534       0.000000
# max         0.266667       0.363636       0.307692       0.142857
#
# [8 rows x 21 columns]

# %% [markdown]
# ### Starting to make base-line with easy methods

# %%
# Importing SKlearn magic

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score, accuracy_score
from sklearn import preprocessing
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# Making 2 Train-Test split
# One (final_test_*) for the final test and second (test_*) for train-test

train_feature_matrix, final_test_feature_matrix,\
train_labels, final_test_labels = train_test_split(feature_matrix, labels, test_size=0.2, random_state=42)
train_feature_matrix_multi, test_feature_matrix_multi,\
train_labels_multi, test_labels_multi = train_test_split(train_feature_matrix, train_labels, test_size=0.2, random_state=42)

# %%
# Data preprocessing
# In our case preprocessing can't make any harm, because we asume all our features are equaly important

scaler = preprocessing.StandardScaler()
train_feature_matrix_multi_scaled = scaler.fit_transform(train_feature_matrix_multi)
test_feature_matrix_multi_scaled = scaler.fit_transform(test_feature_matrix_multi)
final_test_feature_matrix = scaler.fit_transform(final_test_feature_matrix)

# %% [markdown]
# #### Method 1: Random Forest

# %%
# Will try Random Forest

forest = RandomForestClassifier(n_estimators = 3000, max_depth = 6, \
                                max_features = 'sqrt', bootstrap = 'True', n_jobs = -1)

# %%
# Training 
forest.fit(train_feature_matrix_multi, train_labels_multi)

# %%
# Score for test

forest.score(test_feature_matrix_multi, test_labels_multi)
# Out:
# 0.8560534960112623

# %%
# Score for final_test

forest.score(final_test_feature_matrix, final_test_labels)
# Out:
# 0.7664476771468794

# %% [markdown]
# #### Method 2: Logistic Regression

# %%
# Making LogRes class

lr_clf = LogisticRegression(max_iter = 1000000, solver = 'saga', tol = 0.00001, penalty = 'l1', C = 1, class_weight = { 1 : 1 , 0: 1})

# %%
# Training 

lr_clf.fit(train_feature_matrix_multi, train_labels_multi)
# Out:
# LogisticRegression(C=1, class_weight={1: 1, 0: 1}, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=1000000,
#           multi_class='warn', n_jobs=None, penalty='l1', random_state=None,
#           solver='saga', tol=1e-05, verbose=0, warm_start=False)

# %%
# Weights

lr_clf.coef_
# Out:
# array([[-21.28859642,  -1.79541021, -13.5543154 , -13.47211036,
#          52.47993336,  10.56698513,  13.59601874,   2.48519289,
#           4.34622006, -31.17953155,   3.29198522,  13.36918427,
#          12.2993897 ,   7.17287113,  23.51663194,  25.52525025,
#           0.17153342,   0.81424204,  -2.6669882 ]])

# %%
# Score for test (Accuracy and F1-score)

accuracy_log = lr_clf.score(test_feature_matrix_multi, test_labels_multi)

prediction = lr_clf.predict(test_feature_matrix_multi)

f_1 = f1_score(prediction, test_labels_multi)

print('Acuracy = '+str(accuracy_log))
print('F1 score  = '+str(f_1))
# Out:
# Acuracy = 0.8473721257625528
# F1 score  = 0.8933431710116412

# %%
# Score for final_test (Accuracy and F1-score)

accuracy_log = lr_clf.score(final_test_feature_matrix, final_test_labels)

prediction = lr_clf.predict(final_test_feature_matrix)

f_1 = f1_score(prediction, final_test_labels)

print('Acuracy = '+str(accuracy_log))
print('F1 score  = '+str(f_1))
# Out:
# Acuracy = 0.7272641952135148
# F1 score  = 0.7688514158447344

# %% [markdown]
# #### Method 3: Gradient boosting

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
# Making

Gradboost = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=5),
    n_estimators=1600)

# %%
# Fitting

Gradboost.fit(train_feature_matrix_multi, train_labels_multi)# Score for test (Accuracy and F1-score)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R',
#           base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#           learning_rate=1.0, n_estimators=1600, random_state=None)

# %%
# Score for test (Accuracy and F1-score)

accuracy_log = Gradboost.score(test_feature_matrix_multi, test_labels_multi)

prediction = Gradboost.predict(test_feature_matrix_multi)

f_1 = f1_score(prediction, test_labels_multi)

print('Acuracy = '+str(accuracy_log))
print('F1 score  = '+str(f_1))
# Out:
# Acuracy = 0.8922454246832473
# F1 score  = 0.9244250627391287

# %%
# Score for final_test (Accuracy and F1-score)

accuracy_log = Gradboost.score(final_test_feature_matrix, final_test_labels)

prediction = Gradboost.predict(final_test_feature_matrix)

f_1 = f1_score(prediction, final_test_labels)

print('Acuracy = '+str(accuracy_log))
print('F1 score  = '+str(f_1))
# Out:
# Acuracy = 0.7432660722665415
# F1 score  = 0.8387420048928581
